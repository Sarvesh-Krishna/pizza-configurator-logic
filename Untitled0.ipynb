# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarvesh-Krishna/pizza-configurator-logic/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sarvesh-krishna/pizza-configurator-logic.git
# Out:
# fatal: destination path 'pizza-configurator-logic' already exists and is not an empty directory.

# %%
# %cd pizza-configurator-logic
# !python pizza_order.py
# Out:
# [Errno 2] No such file or directory: 'pizza-configurator-logic'
# /content/pizza-configurator-logic
# ------------Welcome------------
# ----------Pizza World----------
# Size of pizza 'p' for personal & 'f' for family:
